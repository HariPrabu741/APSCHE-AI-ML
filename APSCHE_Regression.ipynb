# %%
# Import the required lib

import pandas as pd
import numpy as np

# %%
# Reading the data

df = pd.read_csv('/content/50_Startups.csv')
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# Checking the dtype

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        108 non-null    float64
#  1   Administration   108 non-null    float64
#  2   Marketing Spend  108 non-null    float64
#  3   State            108 non-null    object
#  4   Profit           108 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 4.3+ KB

# %%
# Descriptive stat

df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count     108.000000      108.000000       108.000000     108.000000
# mean    74959.338704   121750.788889    214952.664722  113523.760000
# std     44996.368152    27322.385654    117937.942120   38991.013654
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     38558.510000   105077.645000    134050.070000   90708.190000
# 50%     75791.365000   122699.795000    239452.750000  109543.120000
# 75%    101913.080000   145077.580000    298664.470000  141585.520000
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
# Checking for the null values

df.isnull()
# Out:
#      R&D Spend  Administration  Marketing Spend  State  Profit
# 0        False           False            False  False   False
# 1        False           False            False  False   False
# 2        False           False            False  False   False
# 3        False           False            False  False   False
# 4        False           False            False  False   False
# ..         ...             ...              ...    ...     ...
# 103      False           False            False  False   False
# 104      False           False            False  False   False
# 105      False           False            False  False   False
# 106      False           False            False  False   False
# 107      False           False            False  False   False
#
# [108 rows x 5 columns]

# %%
df.isnull().any()
# Out:
# R&D Spend          False
# Administration     False
# Marketing Spend    False
# State              False
# Profit             False
# dtype: bool

# %%
# Converting object datatype to int

df['State'].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
df['State'].value_counts()
# Out:
# New York      39
# California    36
# Florida       33
# Name: State, dtype: int64

# %%
# Label encoding

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
# column name = le.fit_transform(column name)

# %%
# Manual encoding

df['State'] = df['State'].replace({'New York':0,
                                   'California':1,
                                   'Florida':2})

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State     Profit
# 0  165349.20       136897.80        471784.10      0  192261.83
# 1  162597.70       151377.59        443898.53      1  191792.06
# 2  153441.51       101145.55        407934.54      2  191050.39
# 3  144372.41       118671.85        383199.62      0  182901.99
# 4  142107.34        91391.77        366168.42      2  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        108 non-null    float64
#  1   Administration   108 non-null    float64
#  2   Marketing Spend  108 non-null    float64
#  3   State            108 non-null    int64
#  4   Profit           108 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 4.3 KB

# %%
# Dependent and independent variable

x = df.drop('Profit',axis=1)
y = df['Profit']

# %%
x
# Out:
#      R&D Spend  Administration  Marketing Spend  State
# 0    165349.20       136897.80        471784.10      0
# 1    162597.70       151377.59        443898.53      1
# 2    153441.51       101145.55        407934.54      2
# 3    144372.41       118671.85        383199.62      0
# 4    142107.34        91391.77        366168.42      2
# ..         ...             ...              ...    ...
# 103  119943.24       156547.42        256512.92      2
# 104  114523.61       122616.84        261776.23      0
# 105   78013.11       121597.55        264346.06      1
# 106   94657.16       145077.58        282574.31      0
# 107   91749.16       114175.79        294919.57      2
#
# [108 rows x 4 columns]

# %%
y
# Out:
# 0      192261.83
# 1      191792.06
# 2      191050.39
# 3      182901.99
# 4      166187.94
#          ...
# 103    132602.65
# 104    129917.04
# 105    126992.93
# 106    125370.37
# 107    124266.90
# Name: Profit, Length: 108, dtype: float64

# %%
# Train and test split

from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.25,random_state=12)

# %%
print("The shape of xtrain is {}".format(xtrain.shape))
print("The shape of xtest is {}".format(xtest.shape))
print("The shape of ytrain is {}".format(ytrain.shape))
print("The shape of ytest is {}".format(ytest.shape))
# Out:
# The shape of xtrain is (81, 4)
# The shape of xtest is (27, 4)
# The shape of ytrain is (81,)
# The shape of ytest is (27,)

# %%
# Model Building

from sklearn.linear_model import LinearRegression

# %%
# Initializing Linear regression

lr = LinearRegression()

# %%
# Train the model

lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
# Predicting the model and saving to a variable

ypred = lr.predict(xtest)

# %%
ypred
# Out:
# array([ 77670.98400838, 121105.48937758, 113048.1602188 , 154016.16750334,
#         84513.58545908, 148544.16791123, 128218.24283949, 121105.48937758,
#        109435.6930123 ,  72137.7777111 , 159409.92869125,  77180.89116199,
#         98293.32063942, 132431.17296715, 153142.18082396, 153142.18082396,
#         61709.69306247, 174222.26857343,  61709.69306247, 154016.16750334,
#        128668.22147415, 113048.1602188 , 128668.22147415, 102520.41678047,
#        189979.36896937, 146238.11457759,  72049.04668261])

# %%
ytest
# Out:
# 36      90708.19
# 21     111313.02
# 19     122776.86
# 98     149759.96
# 39      81005.76
# 14     132602.65
# 102    134307.35
# 60     111313.02
# 26     105733.54
# 81      71498.49
# 7      155752.60
# 40      78239.91
# 31      97483.56
# 17     125370.37
# 97     152211.77
# 8      152211.77
# 46      49490.75
# 92     182901.99
# 85      49490.75
# 9      149759.96
# 51     141585.52
# 58     122776.86
# 12     141585.52
# 68     101004.64
# 1      191792.06
# 15     129917.04
# 38      81229.06
# Name: Profit, dtype: float64

# %%
compare = pd.DataFrame([ytest.values,ypred])

# %%
compare = compare.T

# %%
compare
# Out:
#             0              1
# 0    90708.19   77670.984008
# 1   111313.02  121105.489378
# 2   122776.86  113048.160219
# 3   149759.96  154016.167503
# 4    81005.76   84513.585459
# 5   132602.65  148544.167911
# 6   134307.35  128218.242839
# 7   111313.02  121105.489378
# 8   105733.54  109435.693012
# 9    71498.49   72137.777711
# 10  155752.60  159409.928691
# 11   78239.91   77180.891162
# 12   97483.56   98293.320639
# 13  125370.37  132431.172967
# 14  152211.77  153142.180824
# 15  152211.77  153142.180824
# 16   49490.75   61709.693062
# 17  182901.99  174222.268573
# 18   49490.75   61709.693062
# 19  149759.96  154016.167503
# 20  141585.52  128668.221474
# 21  122776.86  113048.160219
# 22  141585.52  128668.221474
# 23  101004.64  102520.416780
# 24  191792.06  189979.368969
# 25  129917.04  146238.114578
# 26   81229.06   72049.046683

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(ytest,ypred)
# Out:
# 75390264.74183239

# %%
# Scaling the data

from sklearn.preprocessing import StandardScaler

# %%
st = StandardScaler()

# %%
xtrain_sc = st.fit_transform(xtrain)

# %%
xtest_sc = st.transform(xtest)

# %%
lr1 = LinearRegression()

# %%
lr1.fit(xtrain_sc,ytrain)
# Out:
# LinearRegression()

# %%
ypred = lr1.predict(xtest_sc)

# %%
mean_squared_error(ytest,ypred)
# Out:
# 75390264.7408362
